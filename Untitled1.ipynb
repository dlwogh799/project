# %%
import numpy as np
import pandas as pd
p = pd.read_csv('C:/cakd5/workspace/project/data/3.22.csv',encoding = 'cp949')
p
# Out:
#        Unnamed: 0   고객번호  성별  연령대  거주지역  경쟁사이용횟수  멤버쉽보유  온라인이용횟수  1번품목구매비율(%)  \
# 0               0      1   1    5     1     15.0    0.0      0.0         2.86
# 1               1      2   1    5     0      8.0    0.0      0.0         3.64
# 2               2      3   1    5     0      0.0    0.0      0.0         4.47
# 3               3      4   0    5     1      3.0    0.0      0.0         2.72
# 4               4      6   0    5     3      0.0    0.0      0.0         4.99
# ...           ...    ...  ..  ...   ...      ...    ...      ...          ...
# 18861       18861  19333   0    1     0      0.0    1.0      5.0        15.53
# 18862       18862  19334   1    2     3     30.0    1.0      0.0        13.88
# 18863       18863  19335   0    2     0      0.0    1.0      0.0        16.72
# 18864       18864  19336   0    2     1      0.0    0.0      0.0        10.66
# 18865       18865  19337   1    1     1      0.0    0.0      0.0         6.46
#
# ...

# %%
p.columns   #  ' 8기 구매비율 '      8기 구매등급  8기 구매횟수   제거
# Out:
# Index(['Unnamed: 0', '고객번호', '성별', '연령대', '거주지역', '경쟁사이용횟수', '멤버쉽보유',
#        '온라인이용횟수', '1번품목구매비율(%)', '2번품목구매비율(%)', '3번품목구매비율(%)', '4번품목구매비율(%)',
#        '편의품구매횟수', '선매품구매횟수', '전문품구매횟수', '기타구매횟수', '편의품구매등급', '선매품구매등급',
#        '전문품구매등급', '기타구매등급', '1기구매비율(%)', '2기구매비율(%)', '3기구매비율(%)', '4기구매비율(%)',
#        '5기구매비율(%)', '6기구매비율(%)', '7기구매비율(%)', '8기구매비율(%)', '1기구매등급', '2기구매등급',
#        '3기구매등급', '4기구매등급', '5기구매등급', '6기구매등급', '7기구매등급', '8기구매등급', '1기구매횟수',
#        '2기구매횟수', '3기구매횟수', '4기구매횟수', '5기구매횟수', '6기구매횟수', '7기구매횟수', '8기구매횟수',
#        'A제휴사구매비율(%)', 'B제휴사구매비율(%)', 'C제휴사구매비율(%)', 'D번제휴사구매비율(%)', 'A_구매횟수',
#        'B_구매횟수', 'C_구매횟수', 'D_구매횟수', 'A_총구매액', 'B_총구매액', 'C_총구매액', 'D_총구매액',
#        '분기증감확인'],
#       dtype='object')

# %%
w =p.drop(['8기구매비율(%)', '8기구매등급','8기구매횟수'], axis=1)
w
# Out:
#        Unnamed: 0   고객번호  성별  연령대  거주지역  경쟁사이용횟수  멤버쉽보유  온라인이용횟수  1번품목구매비율(%)  \
# 0               0      1   1    5     1     15.0    0.0      0.0         2.86
# 1               1      2   1    5     0      8.0    0.0      0.0         3.64
# 2               2      3   1    5     0      0.0    0.0      0.0         4.47
# 3               3      4   0    5     1      3.0    0.0      0.0         2.72
# 4               4      6   0    5     3      0.0    0.0      0.0         4.99
# ...           ...    ...  ..  ...   ...      ...    ...      ...          ...
# 18861       18861  19333   0    1     0      0.0    1.0      5.0        15.53
# 18862       18862  19334   1    2     3     30.0    1.0      0.0        13.88
# 18863       18863  19335   0    2     0      0.0    1.0      0.0        16.72
# 18864       18864  19336   0    2     1      0.0    0.0      0.0        10.66
# 18865       18865  19337   1    1     1      0.0    0.0      0.0         6.46
#
# ...

# %%
w.columns
# Out:
# Index(['Unnamed: 0', '고객번호', '성별', '연령대', '거주지역', '경쟁사이용횟수', '멤버쉽보유',
#        '온라인이용횟수', '1번품목구매비율(%)', '2번품목구매비율(%)', '3번품목구매비율(%)', '4번품목구매비율(%)',
#        '편의품구매횟수', '선매품구매횟수', '전문품구매횟수', '기타구매횟수', '편의품구매등급', '선매품구매등급',
#        '전문품구매등급', '기타구매등급', '1기구매비율(%)', '2기구매비율(%)', '3기구매비율(%)', '4기구매비율(%)',
#        '5기구매비율(%)', '6기구매비율(%)', '7기구매비율(%)', '1기구매등급', '2기구매등급', '3기구매등급',
#        '4기구매등급', '5기구매등급', '6기구매등급', '7기구매등급', '1기구매횟수', '2기구매횟수', '3기구매횟수',
#        '4기구매횟수', '5기구매횟수', '6기구매횟수', '7기구매횟수', 'A제휴사구매비율(%)', 'B제휴사구매비율(%)',
#        'C제휴사구매비율(%)', 'D번제휴사구매비율(%)', 'A_구매횟수', 'B_구매횟수', 'C_구매횟수', 'D_구매횟수',
#        'A_총구매액', 'B_총구매액', 'C_총구매액', 'D_총구매액', '분기증감확인'],
#       dtype='object')

# %%
z = pd.read_csv('C:/cakd5/workspace/project/data/제휴사.csv',encoding = 'cp949')
z
# Out:
#       Unnamed: 0    구매횟수 구매횟수.1  구매횟수.2 구매횟수.3         총구매액     총구매액.1  \
# 0            제휴사       A      B       C      D            A          B
# 1           고객번호     NaN    NaN     NaN    NaN          NaN        NaN
# 2              1   874.0   64.0   119.0    NaN   83024104.0   754018.0
# 3              2  1080.0   16.0     NaN   20.0  101191019.0   207512.0
# 4              3     1.0    2.0  1188.0    NaN      82407.0     7863.0
# ...          ...     ...    ...     ...    ...          ...        ...
# 19380      19379    33.0   29.0    22.0  500.0    1847757.0   324661.0
# 19381      19380     3.0    7.0    42.0  388.0      43212.0    66258.0
# 19382      19381     5.0  791.0     9.0    NaN     401711.0  5747363.0
# 19383      19382     4.0  899.0     3.0    NaN     184724.0  4227018.0
# 19384      19383    18.0   16.0     3.0  223.0    1091172.0    54734.0
#
#           총구매액.2     총구매액.3    평균구매액  평균구매액.1 평균구매액.2  평균구매액.3
# ...

# %%
x = pd.read_csv('C:/cakd5/workspace/project/data/분기.csv',encoding = 'cp949')
x
# Out:
#       Unnamed: 0     구매평균   구매평균.1    구매평균.2   구매평균.3    구매평균.4   구매평균.5  \
# 0             분기     14_1     14_2      14_3     14_4      15_1     15_2
# 1           고객번호      NaN      NaN       NaN      NaN       NaN      NaN
# 2              1  74346.0  94942.0   85782.0  96701.0   54701.0  65837.0
# 3              2  75534.0  67785.0  120631.0  47573.0  128906.0  86066.0
# 4              3   2144.0   2703.0    2977.0   2412.0    3247.0   2523.0
# ...          ...      ...      ...       ...      ...       ...      ...
# 19380      19379      NaN      NaN   13383.0  12373.0    9151.0   9901.0
# 19381      19380      NaN      NaN       NaN  27268.0    7941.0   9183.0
# 19382      19381      NaN      NaN       NaN      NaN    8011.0   7900.0
# 19383      19382      NaN      NaN       NaN      NaN    4571.0   4980.0
# 19384      19383      NaN      NaN       NaN      NaN       NaN   5791.0
#
#          구매평균.6   구매평균.7
# 0          15_3     15_4
# 1           NaN      NaN
# ...

# %%
xx = x.drop(['구매평균.7'], axis=1)
xx
# Out:
#       Unnamed: 0     구매평균   구매평균.1    구매평균.2   구매평균.3    구매평균.4   구매평균.5  \
# 0             분기     14_1     14_2      14_3     14_4      15_1     15_2
# 1           고객번호      NaN      NaN       NaN      NaN       NaN      NaN
# 2              1  74346.0  94942.0   85782.0  96701.0   54701.0  65837.0
# 3              2  75534.0  67785.0  120631.0  47573.0  128906.0  86066.0
# 4              3   2144.0   2703.0    2977.0   2412.0    3247.0   2523.0
# ...          ...      ...      ...       ...      ...       ...      ...
# 19380      19379      NaN      NaN   13383.0  12373.0    9151.0   9901.0
# 19381      19380      NaN      NaN       NaN  27268.0    7941.0   9183.0
# 19382      19381      NaN      NaN       NaN      NaN    8011.0   7900.0
# 19383      19382      NaN      NaN       NaN      NaN    4571.0   4980.0
# 19384      19383      NaN      NaN       NaN      NaN       NaN   5791.0
#
#          구매평균.6
# 0          15_3
# 1           NaN
# 2      120438.0
# 3      123730.0
# ...

# %%
cc = pd.read_csv('C:/cakd5/workspace/project/data/제휴사수정최종.csv',encoding = 'cp949')
cc
# Out:
#         고객번호  A_구매횟수  B_구매횟수  C_구매횟수  D_구매횟수  A_총구매액  B_총구매액  C_총구매액  D_총구매액
# 0          1   874.0    64.0   119.0     0.0     1.0     7.0     3.0     4.0
# 1          2  1080.0    16.0     0.0    20.0     1.0     8.0    10.0     1.0
# 2          3     1.0     2.0  1188.0     0.0    10.0    10.0     3.0     8.0
# 3          4   649.0   126.0   155.0     0.0     4.0     6.0     4.0     8.0
# 4          6   361.0  1193.0    39.0     0.0     4.0     3.0     4.0     8.0
# ...      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 18861  19333   427.0   302.0    11.0    84.0     6.0     7.0     7.0     1.0
# 18862  19334     3.0  1674.0   287.0     0.0     8.0     2.0     4.0     5.0
# 18863  19335    10.0  1496.0   367.0     0.0     7.0     2.0     3.0     5.0
# 18864  19336   434.0     1.0     0.0     5.0     3.0    10.0     9.0     1.0
# 18865  19337     5.0    11.0  1305.0     0.0     9.0     8.0     3.0    10.0
#
# [18866 rows x 9 columns]

# %%
qq = pd.read_csv('C:/cakd5/workspace/project/data/분기1.csv',encoding = 'cp949')
qq
# Out:
#       Unnamed: 0     구매평균   구매평균.1    구매평균.2   구매평균.3    구매평균.4   구매평균.5  \
# 0             분기     14_1     14_2      14_3     14_4      15_1     15_2
# 1           고객번호      NaN      NaN       NaN      NaN       NaN      NaN
# 2              1  74346.0  94942.0   85782.0  96701.0   54701.0  65837.0
# 3              2  75534.0  67785.0  120631.0  47573.0  128906.0  86066.0
# 4              3   2144.0   2703.0    2977.0   2412.0    3247.0   2523.0
# ...          ...      ...      ...       ...      ...       ...      ...
# 19380      19379      NaN      NaN   13383.0  12373.0    9151.0   9901.0
# 19381      19380      NaN      NaN       NaN  27268.0    7941.0   9183.0
# 19382      19381      NaN      NaN       NaN      NaN    8011.0   7900.0
# 19383      19382      NaN      NaN       NaN      NaN    4571.0   4980.0
# 19384      19383      NaN      NaN       NaN      NaN       NaN   5791.0
#
#          구매평균.6   구매평균.7   구매횟수  ... 구매횟수.6 구매횟수.7        총구매액      총구매액.1  \
# ...

# %%
qqq = qq.drop(['구매평균.7', '구매횟수.7','총구매액.7'],axis=1)
qqq
# Out:
#       Unnamed: 0     구매평균   구매평균.1    구매평균.2   구매평균.3    구매평균.4   구매평균.5  \
# 0             분기     14_1     14_2      14_3     14_4      15_1     15_2
# 1           고객번호      NaN      NaN       NaN      NaN       NaN      NaN
# 2              1  74346.0  94942.0   85782.0  96701.0   54701.0  65837.0
# 3              2  75534.0  67785.0  120631.0  47573.0  128906.0  86066.0
# 4              3   2144.0   2703.0    2977.0   2412.0    3247.0   2523.0
# ...          ...      ...      ...       ...      ...       ...      ...
# 19380      19379      NaN      NaN   13383.0  12373.0    9151.0   9901.0
# 19381      19380      NaN      NaN       NaN  27268.0    7941.0   9183.0
# 19382      19381      NaN      NaN       NaN      NaN    8011.0   7900.0
# 19383      19382      NaN      NaN       NaN      NaN    4571.0   4980.0
# 19384      19383      NaN      NaN       NaN      NaN       NaN   5791.0
#
#          구매평균.6   구매횟수 구매횟수.1  ... 구매횟수.4 구매횟수.5 구매횟수.6        총구매액  \
# ...

# %%
c = pd.read_csv('C:/cakd5/workspace/project/data/제휴사구매횟수.csv',encoding = 'cp949')
c
# Out:
#        Unnamed: 0   고객번호  A_구매횟수  B_구매횟수  C_구매횟수  D_구매횟수
# 0               0      1   874.0    64.0   119.0     0.0
# 1               1      2  1080.0    16.0     0.0    20.0
# 2               2      3     1.0     2.0  1188.0     0.0
# 3               3      4   649.0   126.0   155.0     0.0
# 4               4      6   361.0  1193.0    39.0     0.0
# ...           ...    ...     ...     ...     ...     ...
# 18861       18861  19333   427.0   302.0    11.0    84.0
# 18862       18862  19334     3.0  1674.0   287.0     0.0
# 18863       18863  19335    10.0  1496.0   367.0     0.0
# 18864       18864  19336   434.0     1.0     0.0     5.0
# 18865       18865  19337     5.0    11.0  1305.0     0.0
#
# [18866 rows x 6 columns]

# %%
q = pd.read_csv('C:/cakd5/workspace/project/data/매출등급.csv',encoding = 'cp949')
q
# Out:
#        Unnamed: 0   고객번호  1기구매등급  2기구매등급  3기구매등급  4기구매등급  5기구매등급  6기구매등급  \
# 0            1870      1     1.0     1.0     1.0     1.0     2.0     2.0
# 1             911      2     1.0     1.0     1.0     2.0     1.0     2.0
# 2           18376      3    10.0    10.0    10.0    10.0    10.0    10.0
# 3           13075      4     7.0     3.0     5.0     6.0     7.0     6.0
# 4            8538      6     5.0     4.0     4.0     4.0     4.0     4.0
# ...           ...    ...     ...     ...     ...     ...     ...     ...
# 18861       17449  19333    10.0     9.0    10.0    10.0    10.0    10.0
# 18862       16326  19334     9.0     4.0     4.0     5.0     7.0    10.0
# 18863       15663  19335     9.0     4.0     5.0     6.0     5.0     4.0
# 18864       18014  19336    10.0     4.0     4.0     3.0     4.0     4.0
# 18865       18836  19337    10.0    10.0    10.0    10.0    10.0    10.0
#
#        7기구매등급  8기구매등급  1기구매횟수  2기구매횟수  3기구매횟수  4기구매횟수  5기구매횟수  6기구매횟수  7기구매횟수  \
# ...

# %%
q1 = q.drop(['8기구매등급','8기구매횟수'], axis=1)
q1
# Out:
#        Unnamed: 0   고객번호  1기구매등급  2기구매등급  3기구매등급  4기구매등급  5기구매등급  6기구매등급  \
# 0            1870      1     1.0     1.0     1.0     1.0     2.0     2.0
# 1             911      2     1.0     1.0     1.0     2.0     1.0     2.0
# 2           18376      3    10.0    10.0    10.0    10.0    10.0    10.0
# 3           13075      4     7.0     3.0     5.0     6.0     7.0     6.0
# 4            8538      6     5.0     4.0     4.0     4.0     4.0     4.0
# ...           ...    ...     ...     ...     ...     ...     ...     ...
# 18861       17449  19333    10.0     9.0    10.0    10.0    10.0    10.0
# 18862       16326  19334     9.0     4.0     4.0     5.0     7.0    10.0
# 18863       15663  19335     9.0     4.0     5.0     6.0     5.0     4.0
# 18864       18014  19336    10.0     4.0     4.0     3.0     4.0     4.0
# 18865       18836  19337    10.0    10.0    10.0    10.0    10.0    10.0
#
#        7기구매등급  1기구매횟수  2기구매횟수  3기구매횟수  4기구매횟수  5기구매횟수  6기구매횟수  7기구매횟수
# ...

# %%
d = pd.read_csv('C:/cakd5/workspace/project/data/제휴사라벨링.csv',encoding = 'cp949')
d
# Out:
#        Unnamed: 0     고객번호  A_구매횟수  B_구매횟수  C_구매횟수  D_구매횟수  A_총구매액  B_총구매액  \
# 0               0   9384.0     1.0    10.0    10.0     1.0     1.0    10.0
# 1               1   7267.0     1.0     9.0     4.0    10.0     2.0     9.0
# 2               2   4829.0     1.0     7.0     9.0     1.0     4.0     8.0
# 3               3   3931.0     1.0     8.0     7.0     1.0     3.0     8.0
# 4               4    701.0     1.0    10.0     3.0     7.0     1.0     9.0
# ...           ...      ...     ...     ...     ...     ...     ...     ...
# 18861       18861   9910.0    10.0    10.0     2.0     9.0    10.0     9.0
# 18862       18862   2467.0    10.0     9.0     1.0     8.0    10.0    10.0
# 18863       18863  11916.0    10.0     7.0     1.0     3.0    10.0     8.0
# 18864       18864  18383.0    10.0     2.0     9.0     2.0    10.0     2.0
# 18865       18865   4398.0    10.0     3.0     8.0     7.0    10.0     2.0
#
#        C_총구매액  D_총구매액
# 0        10.0     1.0
# ...

# %%
r = pd.read_csv('C:/cakd5/workspace/project/data/PRODCL2.csv')
r
# Out:
#         소분류코드  상품분류
# 0     A010101  생활잡화
# 1     A010102  생활잡화
# 2     A010103  생활잡화
# 3     A010104  생활잡화
# 4     A010105  생활잡화
# ...       ...   ...
# 4381  D080204   화장품
# 4382  D080205   화장품
# 4383  D080301   화장품
# 4384  D080302   화장품
# 4385  D080401   화장품
#
# [4386 rows x 2 columns]

# %%
d = pd.read_csv('C:/cakd5/workspace/project/data/3.22.csv',encoding = 'cp949')
d
# Out:
#        Unnamed: 0   고객번호  성별  연령대  거주지역  경쟁사이용횟수  멤버쉽보유  온라인이용횟수  1번품목구매비율(%)  \
# 0               0      1   1    5     1     15.0    0.0      0.0         2.86
# 1               1      2   1    5     0      8.0    0.0      0.0         3.64
# 2               2      3   1    5     0      0.0    0.0      0.0         4.47
# 3               3      4   0    5     1      3.0    0.0      0.0         2.72
# 4               4      6   0    5     3      0.0    0.0      0.0         4.99
# ...           ...    ...  ..  ...   ...      ...    ...      ...          ...
# 18861       18861  19333   0    1     0      0.0    1.0      5.0        15.53
# 18862       18862  19334   1    2     3     30.0    1.0      0.0        13.88
# 18863       18863  19335   0    2     0      0.0    1.0      0.0        16.72
# 18864       18864  19336   0    2     1      0.0    0.0      0.0        10.66
# 18865       18865  19337   1    1     1      0.0    0.0      0.0         6.46
#
# ...

# %%
b = pd.read_csv('C:/cakd5/workspace/project/data/제휴사B.csv',encoding = 'cp949')
b
# Out:
#          제휴사     영수증번호  대분류코드  중분류코드    소분류코드   고객번호  점포코드      구매일자  구매시간  \
# 0          B   8750675     12   1206  B120605  12231    44  20150715    16
# 1          B   8750676      6    604  B060403   6422    44  20150715    16
# 2          B   8750676     89   8901  B890101   6422    44  20150715    16
# 3          B   8750677      1    101  B010108   2041    44  20150715    17
# 4          B   8750677     16   1601  B160101   2041    44  20150715    17
# ...       ..       ...    ...    ...      ...    ...   ...       ...   ...
# 28593025   A   4019586      9    902  A090201   7430    14  20150404    21
# 28593026   B   6929124     12   1206  B120602   2028    11  20150907    21
# 28593027   B   8483208     64   6404  B640404   8206    36  20150627    20
# 28593028   B  10501963     81   8102  B810201  11920   113  20141121    20
# 28593029   C   1020704      3    303  C030306  14823    68  20141219    17
#
#            구매금액  YEAR  MONTH
# 0          6824  2015      7
# ...

# %%
# %%time
import cx_Oracle
import numpy as np
import pandas as pd

#고객별 2014년 2015년 총구매액 및 평균구매액 출력
conn=cx_Oracle.connect('LM_PDB/LM@localhost:1521/xepdb1')
cursor = conn.cursor()
# Out:
# Wall time: 3.69 s

# %%
cursor.execute('고객번호 고객번호,제휴사 제휴사B,sum(구매금액) 구매금액 from s_pur_copy where 구매일자 between 20140101 and 20150930 and 제휴사 = 'B' group by 제휴사,고객번호 order by 고객번호')
x = cursor.fetchall()

df2 = pd.DataFrame(x, columns=['고객번호','제휴사','구매금액'])
df2
# Out:
#   File "C:\Users\dlwog\AppData\Local\Temp/ipykernel_17624/4262753292.py", line 1
#     cursor.execute('고객번호 고객번호,제휴사 제휴사B,sum(구매금액) 구매금액 from s_pur_copy where 구매일자 between 20140101 and 20150930 and 제휴사 = 'B' group by 제휴사,고객번호 order by 고객번호')
#
# ^
# SyntaxError: bytes can only contain ASCII literal characters.

# %%
b1 = b[['고객번호','제휴사','구매일자','구매금액']] 
b1
# Out:
#            고객번호 제휴사      구매일자   구매금액
# 0         12231   B  20150715   6824
# 1          6422   B  20150715   8244
# 2          6422   B  20150715   3171
# 3          2041   B  20150715    494
# 4          2041   B  20150715   8143
# ...         ...  ..       ...    ...
# 28593025   7430   A  20150404  52206
# 28593026   2028   B  20150907  15170
# 28593027   8206   B  20150627  22538
# 28593028  11920   B  20141121   3020
# 28593029  14823   C  20141219   1179
#
# [28593030 rows x 4 columns]

# %%
b2 =  pd.read_csv('C:/cakd5/workspace/project/data/분기품목.csv',encoding = 'cp949')
b2
# Out:
#         고객번호  ('구매횟수', '14_1', '가구류')  ('구매횟수', '14_1', '고급식료품')  \
# 0          1                      1.0                        1.0
# 1          2                      7.0                        NaN
# 2          3                      NaN                        NaN
# 3          4                      NaN                        NaN
# 4          6                      NaN                        2.0
# ...      ...                      ...                        ...
# 18861  19333                      NaN                        1.0
# 18862  19334                      NaN                        NaN
# 18863  19335                      4.0                        NaN
# 18864  19336                      NaN                        NaN
# 18865  19337                      NaN                        NaN
#
#        ('구매횟수', '14_1', '기타')  ('구매횟수', '14_1', '기호품')  \
# 0                         5.0                      5.0
# 1                         1.0                      5.0
# ...

# %%
b2.columns
# Out:
# Index(['고객번호', '('구매횟수', '14_1', '가구류')', '('구매횟수', '14_1', '고급식료품')',
#        '('구매횟수', '14_1', '기타')', '('구매횟수', '14_1', '기호품')',
#        '('구매횟수', '14_1', '도서음반')', '('구매횟수', '14_1', '레저취미')',
#        '('구매횟수', '14_1', '문구류')', '('구매횟수', '14_1', '사치품')',
#        '('구매횟수', '14_1', '생활잡화')',
#        ...
#        '('총구매액', '15_4', '도서음반')', '('총구매액', '15_4', '레저취미')',
#        '('총구매액', '15_4', '문구류')', '('총구매액', '15_4', '사치품')',
#        '('총구매액', '15_4', '생활잡화')', '('총구매액', '15_4', '식료품')',
#        '('총구매액', '15_4', '의류잡화')', '('총구매액', '15_4', '전자제품')',
#        '('총구매액', '15_4', '차량용품')', '('총구매액', '15_4', '화장품')'],
#       dtype='object', length=225)

# %%
b3 = b2(['구매횟수', '14_1', '가구류'])+ b2(['구매횟수', '14_2', '가구류'])
b3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17624/1806857626.py in <module>
# ----> 1 b3 = b2(['구매횟수', '14_1', '가구류'])+ b2(['구매횟수', '14_2', '가구류'])
#       2 b3
#
# TypeError: 'DataFrame' object is not callable

# %%
pd.set_option('display.max_seq_items', None)  # 쥬피터의 많거나 길어서 생기는 .....생략을 없애는 코드

# %%
b2.columns
# Out:
# Index(['고객번호', '('구매횟수', '14_1', '가구류')', '('구매횟수', '14_1', '고급식료품')',
#        '('구매횟수', '14_1', '기타')', '('구매횟수', '14_1', '기호품')',
#        '('구매횟수', '14_1', '도서음반')', '('구매횟수', '14_1', '레저취미')',
#        '('구매횟수', '14_1', '문구류')', '('구매횟수', '14_1', '사치품')',
#        '('구매횟수', '14_1', '생활잡화')', '('구매횟수', '14_1', '식료품')',
#        '('구매횟수', '14_1', '의류잡화')', '('구매횟수', '14_1', '전자제품')',
#        '('구매횟수', '14_1', '차량용품')', '('구매횟수', '14_1', '화장품')',
#        '('구매횟수', '14_2', '가구류')', '('구매횟수', '14_2', '고급식료품')',
#        '('구매횟수', '14_2', '기타')', '('구매횟수', '14_2', '기호품')',
#        '('구매횟수', '14_2', '도서음반')', '('구매횟수', '14_2', '레저취미')',
#        '('구매횟수', '14_2', '문구류')', '('구매횟수', '14_2', '사치품')',
#        '('구매횟수', '14_2', '생활잡화')', '('구매횟수', '14_2', '식료품')',
#        '('구매횟수', '14_2', '의류잡화')', '('구매횟수', '14_2', '전자제품')',
#        '('구매횟수', '14_2', '차량용품')', '('구매횟수', '14_2', '화장품')',
#        '('구매횟수', '14_3', '가구류')', '('구매횟수', '14_3', '고급식료품')',
# ...

# %%
b3 =  pd.read_csv('C:/cakd5/workspace/project/data/공백제거.csv')
b3
# Out:
#         소분류코드  상품분류
# 0     A010101  생활잡화
# 1     A010102  생활잡화
# 2     A010103  생활잡화
# 3     A010104  생활잡화
# 4     A010105  생활잡화
# ...       ...   ...
# 4381  D080204   화장품
# 4382  D080205   화장품
# 4383  D080301   화장품
# 4384  D080302   화장품
# 4385  D080401   화장품
#
# [4386 rows x 2 columns]

# %%
ww = pd.read_csv('C:/cakd5/workspace/project/data/test2.csv')
ww
# Out:
#        00001   717576
# 0          2   209450
# 1          3     6960
# 2          4  1303916
# 3          5    16000
# 4          6  7350687
# ...      ...      ...
# 18306  19379   300980
# 18307  19380    60280
# 18308  19381  4301032
# 18309  19382  2917826
# 18310  19383    48600
#
# [18311 rows x 2 columns]

# %%
ww.sum()
# Out:
# 00001       175956982
# 717576    98456353833
# dtype: int64
